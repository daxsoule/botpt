# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
o1_kita = pd.read_csv('/home/jovyan/data/volcanyc/O1/Kita_o1_table.txt', delim_whitespace=True, dtype=object)
df_o1_kita = pd.DataFrame(o1_kita).astype(float)
del df_o1_kita['Longitude']
del df_o1_kita['Latitude']
df_o1_kita
# Out:
#       Distance  Elevation
# 0     0.000000 -1294.7291
# 1     0.036429 -1293.3230
# 2     0.072858 -1291.8481
# 3     0.109287 -1290.3452
# 4     0.145716 -1288.8723
# ..         ...        ...
# 521  18.979395 -1202.3578
# 522  19.015823 -1201.4120
# 523  19.052252 -1200.5450
# 524  19.088680 -1200.1809
# 525  19.125109 -1200.4017
#
# [526 rows x 2 columns]

# %%
o1_knoll = pd.read_csv('/home/jovyan/data/volcanyc/O1/knoll_01_table.txt', delim_whitespace=True, dtype=object)
df_o1_knoll = pd.DataFrame(o1_knoll).astype(float)
del df_o1_knoll['Longitude']
del df_o1_knoll['Latitude']
df_o1_knoll
# Out:
#      Distance  Elevation
# 0    0.000000 -1075.6718
# 1    0.043182 -1074.7584
# 2    0.086364 -1075.9346
# 3    0.129546 -1079.2030
# 4    0.172727 -1082.9675
# ..        ...        ...
# 217  9.370451 -1176.8551
# 218  9.413632 -1182.0547
# 219  9.456814 -1187.1505
# 220  9.499995 -1192.3661
# 221  9.543177 -1197.6748
#
# [222 rows x 2 columns]

# %%
o1_O = pd.read_csv('/home/jovyan/data/volcanyc/O1/volcano_O_o1_table.txt', delim_whitespace=True, dtype=object)
df_o1_O = pd.DataFrame(o1_O).astype(float)
del df_o1_O['Longitude']
del df_o1_O['Latitude']
df_o1_O
# Out:
#       Distance  Elevation
# 0     0.000000 -2570.5422
# 1     0.077029 -2567.9840
# 2     0.154059 -2568.2922
# 3     0.231088 -2569.2890
# 4     0.308118 -2567.5200
# ..         ...        ...
# 296  22.800762 -2123.7360
# 297  22.877792 -2127.0150
# 298  22.954823 -2128.7534
# 299  23.031853 -2136.0115
# 300  23.108883 -2143.8276
#
# [301 rows x 2 columns]

# %%
o1_wm = pd.read_csv('/home/jovyan/data/volcanyc/O1/wm_o1_table.txt', delim_whitespace=True, dtype=object)
df_o1_wm = pd.DataFrame(o1_wm).astype(float)
del df_o1_wm['Longitude']
del df_o1_wm['Latitude']
df_o1_wm
# Out:
#      Distance  Elevation
# 0    0.000000 -3007.1480
# 1    0.077228 -3007.1946
# 2    0.154455 -3007.5710
# 3    0.231683 -3005.8777
# 4    0.308911 -2997.8620
# ..        ...        ...
# 124  9.576233        NaN
# 125  9.653460        NaN
# 126  9.730688        NaN
# 127  9.807916        NaN
# 128  9.885143        NaN
#
# [129 rows x 2 columns]

# %%
o1_frsc5 = pd.read_csv('/home/jovyan/data/volcanyc/O1/frsc5_o1_table.txt', delim_whitespace=True, dtype=object)
df_o1_frsc5 = pd.DataFrame(o1_frsc5).astype(float)
del df_o1_frsc5['Longitude']
del df_o1_frsc5['Latitude']
df_o1_frsc5
# Out:
#       Distance  Elevation
# 0     0.000000 -2527.5293
# 1     0.163688 -2581.3310
# 2     0.327377 -2600.4858
# 3     0.491065 -2600.0625
# 4     0.654753 -2599.3930
# ..         ...        ...
# 125  20.461065 -2740.7085
# 126  20.624754 -2744.8955
# 127  20.788443 -2744.0176
# 128  20.952131 -2735.1143
# 129  21.115820 -2732.5083
#
# [130 rows x 2 columns]

# %%
o1_x = pd.read_csv('/home/jovyan/data/volcanyc/O1/seamount_x_oblique_1_tbl.txt', delim_whitespace=True, dtype=object)
df_o1_x = pd.DataFrame(o1_x).astype(float)
del df_o1_x['Longitude']
del df_o1_x['Latitude']
df_o1_x
# Out:
#       Distance  Elevation
# 0     0.000000 -3609.7144
# 1     0.053907 -3609.5012
# 2     0.107815 -3611.2642
# 3     0.161723 -3614.6900
# 4     0.215630 -3618.1897
# ..         ...        ...
# 380  20.484827 -3846.9014
# 381  20.538734 -3847.0623
# 382  20.592642 -3847.6614
# 383  20.646550 -3848.6548
# 384  20.700457 -3849.7588
#
# [385 rows x 2 columns]

# %%
o1_c = pd.read_csv('/home/jovyan/data/volcanyc/O1/seamount_c_oblique_1_tbl.txt', delim_whitespace=True, dtype=object)
df_o1_c = pd.DataFrame(o1_c).astype(float)
del df_o1_c['Longitude']
del df_o1_c['Latitude']
df_o1_c
# Out:
#       Distance  Elevation
# 0     0.000000 -3302.4873
# 1     0.031735 -3304.7876
# 2     0.063470 -3306.7302
# 3     0.095205 -3307.7966
# 4     0.126940 -3307.7583
# ..         ...        ...
# 475  15.074199 -3379.3022
# 476  15.105934 -3378.7737
# 477  15.137670 -3378.0576
# 478  15.169405 -3377.4417
# 479  15.201140 -3377.5964
#
# [480 rows x 2 columns]

# %%
o1_forecast = pd.read_csv('/home/jovyan/data/volcanyc/O1/forecast_seamount_oblique_1_tbl.txt', delim_whitespace=True, dtype=object)
df_o1_forecast = pd.DataFrame(o1_forecast).astype(float)
del df_o1_forecast['Longitude']
del df_o1_forecast['Latitude']
df_o1_forecast
# Out:
#       Distance  Elevation
# 0     0.000000 -3618.5580
# 1     0.053848 -3619.7030
# 2     0.107696 -3620.3242
# 3     0.161544 -3621.7310
# 4     0.215393 -3624.1760
# ..         ...        ...
# 339  18.254543 -3208.3481
# 340  18.308392 -3216.1985
# 341  18.362240 -3222.9020
# 342  18.416088 -3229.2124
# 343  18.469936 -3233.6619
#
# [344 rows x 2 columns]

# %%
o1_orca = pd.read_csv('/home/jovyan/data/volcanyc/O1/orca_oblique_1_tbl.txt', delim_whitespace=True, dtype=object)
df_o1_orca = pd.DataFrame(o1_orca).astype(float)
del df_o1_orca['Longitude']
del df_o1_orca['Latitude']
df_o1_orca
# Out:
#       Distance  Elevation
# 0     0.000000 -1554.3119
# 1     0.020977 -1553.4806
# 2     0.041955 -1552.8949
# 3     0.062932 -1552.6581
# 4     0.083909 -1552.5497
# ..         ...        ...
# 622  13.047838 -1420.9694
# 623  13.068815 -1421.2837
# 624  13.089792 -1421.5226
# 625  13.110769 -1421.7432
# 626  13.131746 -1421.9557
#
# [627 rows x 2 columns]

# %%
ax = df_o1_forecast.plot(y='Elevation')
df_o1_wm['Elevation'].plot(ax=ax)
df_o1_x['Elevation'].plot(ax=ax)
df_o1_orca['Elevation'].plot(ax=ax)
df_o1_knoll['Elevation'].plot(ax=ax)
df_o1_frsc5['Elevation'].plot(ax=ax)
ax.set_ylabel('Elevation (m)')
ax.set_xlabel('Distance (m)')
ax.legend(['Forecast', 'West Mata', 'Volcano X', 'Orca', 'Knoll', 'FRSC 5'])
ax.set_title('Oblique East of Axis')
plt.savefig('o1_peaks')

# %%
ax = df_o1_kita.plot(y='Elevation')
# df_aa_knoll['Elevation'].plot(ax=ax)
df_o1_O['Elevation'].plot(ax=ax)
df_o1_c['Elevation'].plot(ax=ax)
df_o1_orca['Elevation'].plot(ax=ax)
# ax.set_ylabel('Depth (m)')
ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.legend(['Kita', 'Volcano O', 'Seamount C','Orca'])
ax.set_title('Oblique East of Axis')
plt.savefig('o1_caldera')
