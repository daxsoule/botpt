# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
o2_kita = pd.read_csv('/home/jovyan/data/volcanyc/O2/kita_o2_table_et.txt', delim_whitespace=True, dtype=object)
df_o2_kita = pd.DataFrame(o2_kita).astype(float)
del df_o2_kita['Longitude']
del df_o2_kita['Latitude']
df_o2_kita
# Out:
#       Distance  Elevation
# 0     0.000000 -1540.0289
# 1     0.036431 -1539.4874
# 2     0.072862 -1539.3018
# 3     0.109293 -1539.4685
# 4     0.145725 -1539.7650
# ..         ...        ...
# 535  19.490658 -1233.5304
# 536  19.527088 -1233.7186
# 537  19.563519 -1234.8273
# 538  19.599949 -1237.4049
# 539  19.636380 -1240.7758
#
# [540 rows x 2 columns]

# %%
o2_knoll = pd.read_csv('/home/jovyan/data/volcanyc/O2/knoll_o2_table_et.txt', delim_whitespace=True, dtype=object)
df_o2_knoll = pd.DataFrame(o2_knoll).astype(float)
del df_o2_knoll['Longitude']
del df_o2_knoll['Latitude']
df_o2_knoll
# Out:
#      Distance   Elevation
# 0    0.000000 -1119.49670
# 1    0.043208 -1120.37240
# 2    0.086415 -1120.72530
# 3    0.129623 -1120.78090
# 4    0.172830 -1120.19590
# ..        ...         ...
# 226  9.764930  -981.06240
# 227  9.808137  -982.38380
# 228  9.851345  -983.10333
# 229  9.894552  -983.46360
# 230  9.937759  -983.39550
#
# [231 rows x 2 columns]

# %%
o2_tracy = pd.read_csv('/home/jovyan/data/volcanyc/O2/tracy_o2_table_et.txt', delim_whitespace=True, dtype=object)
df_o2_tracy = pd.DataFrame(o2_tracy).astype(float)
del df_o2_tracy['Longitude']
del df_o2_tracy['Latitude']
df_o2_tracy
# Out:
#       Distance  Elevation
# 0     0.000000 -2927.1672
# 1     0.077818 -2916.8486
# 2     0.155637 -2896.6140
# 3     0.233455 -2894.4740
# 4     0.311274 -2873.4556
# ..         ...        ...
# 226  17.586998 -2226.7253
# 227  17.664816 -2237.3410
# 228  17.742634 -2246.5542
# 229  17.820452 -2257.6821
# 230  17.898270 -2268.8792
#
# [231 rows x 2 columns]

# %%
o2_O = pd.read_csv('/home/jovyan/data/volcanyc/O2/volcano_o_02_table_et.txt', delim_whitespace=True, dtype=object)
df_o2_O = pd.DataFrame(o2_O).astype(float)
del df_o2_O['Longitude']
del df_o2_O['Latitude']
df_o2_O
# Out:
#       Distance  Elevation
# 0     0.000000 -1961.7520
# 1     0.076900 -1959.9550
# 2     0.153799 -1958.5566
# 3     0.230699 -1956.9559
# 4     0.307599 -1955.0676
# ..         ...        ...
# 228  17.533123 -2244.4219
# 229  17.610023 -2247.3926
# 230  17.686924 -2251.1807
# 231  17.763824 -2257.8203
# 232  17.840725 -2267.6180
#
# [233 rows x 2 columns]

# %%
o2_wm = pd.read_csv('/home/jovyan/data/volcanyc/O2/wm_o2_table_et.txt', delim_whitespace=True, dtype=object)
df_o2_wm = pd.DataFrame(o2_wm).astype(float)
del df_o2_wm['Longitude']
del df_o2_wm['Latitude']
df_o2_wm
# Out:
#      Distance  Elevation
# 0    0.000000 -2927.8020
# 1    0.077464 -2896.6064
# 2    0.154928 -2887.3975
# 3    0.232392 -2906.1165
# 4    0.309856 -2924.2480
# ..        ...        ...
# 121  9.373157 -2596.3206
# 122  9.450622 -2604.3389
# 123  9.528086 -2618.3818
# 124  9.605550 -2631.8186
# 125  9.683014 -2644.2544
#
# [126 rows x 2 columns]

# %%
o2_frsc5 = pd.read_csv('/home/jovyan/data/volcanyc/O2/frsc5_o2_table.txt', delim_whitespace=True, dtype=object)
df_o2_frsc5 = pd.DataFrame(o2_frsc5).astype(float)
del df_o2_frsc5['Longitude']
del df_o2_frsc5['Latitude']
df_o2_frsc5
# Out:
#       Distance  Elevation
# 0     0.000000 -2693.4753
# 1     0.164122 -2688.8997
# 2     0.328244 -2690.1257
# 3     0.492366 -2689.8464
# 4     0.656488 -2695.7030
# ..         ...        ...
# 108  17.725185 -2484.9316
# 109  17.889307 -2511.0557
# 110  18.053429 -2498.5415
# 111  18.217550 -2475.4038
# 112  18.381672 -2456.3801
#
# [113 rows x 2 columns]

# %%
o2_x = pd.read_csv('/home/jovyan/data/volcanyc/O2/seamount_x_oblique_2_tbl.txt', delim_whitespace=True, dtype=object)
df_o2_x = pd.DataFrame(o2_x).astype(float)
del df_o2_x['Longitude']
del df_o2_x['Latitude']
df_o2_x
# Out:
#       Distance  Elevation
# 0     0.000000 -2800.8767
# 1     0.053896 -2780.0798
# 2     0.107791 -2767.9040
# 3     0.161687 -2760.6604
# 4     0.215582 -2753.5180
# ..         ...        ...
# 344  18.540104 -3751.6750
# 345  18.594000 -3755.0679
# 346  18.647896 -3759.6343
# 347  18.701792 -3763.9036
# 348  18.755688 -3766.0574
#
# [349 rows x 2 columns]

# %%
o2_c = pd.read_csv('/home/jovyan/data/volcanyc/O2/seamount_c_oblique_2_tbl.txt', delim_whitespace=True, dtype=object)
df_o2_c = pd.DataFrame(o2_c).astype(float)
del df_o2_c['Longitude']
del df_o2_c['Latitude']
df_o2_c
# Out:
#       Distance  Elevation
# 0     0.000000 -3218.4653
# 1     0.031739 -3218.9620
# 2     0.063478 -3220.0452
# 3     0.095217 -3221.0410
# 4     0.126956 -3221.1511
# ..         ...        ...
# 495  15.710891 -3513.7222
# 496  15.742630 -3512.1987
# 497  15.774369 -3508.5170
# 498  15.806108 -3504.0535
# 499  15.837848 -3499.6390
#
# [500 rows x 2 columns]

# %%
o2_forecast = pd.read_csv('/home/jovyan/data/volcanyc/O2/forecast_seamount_oblique_2_tbl.txt', delim_whitespace=True, dtype=object)
df_o2_forecast = pd.DataFrame(o2_forecast).astype(float)
del df_o2_forecast['Longitude']
del df_o2_forecast['Latitude']
df_o2_forecast
# Out:
#       Distance  Elevation
# 0     0.000000 -3187.9038
# 1     0.053832 -3195.1190
# 2     0.107665 -3194.2660
# 3     0.161497 -3187.4020
# 4     0.215329 -3176.2625
# ..         ...        ...
# 325  17.495462 -3229.6787
# 326  17.549295 -3233.7870
# 327  17.603128 -3255.0295
# 328  17.656961 -3284.8962
# 329  17.710794 -3316.2056
#
# [330 rows x 2 columns]

# %%
o2_orca = pd.read_csv('/home/jovyan/data/volcanyc/O2/orca_oblique_2_tbl.txt', delim_whitespace=True, dtype=object)
df_o2_orca = pd.DataFrame(o2_orca).astype(float)
del df_o2_orca['Longitude']
del df_o2_orca['Latitude']
df_o2_orca
# Out:
#       Distance  Elevation
# 0     0.000000 -1329.1415
# 1     0.020965 -1328.6615
# 2     0.041930 -1328.3915
# 3     0.062896 -1328.2375
# 4     0.083861 -1328.4210
# ..         ...        ...
# 839  17.590025 -1694.6649
# 840  17.610990 -1697.5802
# 841  17.631956 -1698.4988
# 842  17.652922 -1703.9810
# 843  17.673887 -1702.9312
#
# [844 rows x 2 columns]

# %%
ax = df_o2_forecast.plot(y='Elevation')
df_o2_wm['Elevation'].plot(ax=ax)
df_o2_x['Elevation'].plot(ax=ax)
df_o2_orca['Elevation'].plot(ax=ax)
df_o2_knoll['Elevation'].plot(ax=ax)
df_o2_frsc5['Elevation'].plot(ax=ax)
ax.set_ylabel('Elevation (m)')
ax.set_xlabel('Distance (m)')
ax.legend(['Forecast', 'West Mata', 'Volcano X', 'Orca', 'Knoll', 'FRSC 5'])
ax.set_title('O2')
plt.savefig('o2_peaks')

# %%
ax = df_o2_kita.plot(y='Elevation')
# df_aa_knoll['Elevation'].plot(ax=ax)
df_o2_O['Elevation'].plot(ax=ax)
df_o2_c['Elevation'].plot(ax=ax)
df_o2_orca['Elevation'].plot(ax=ax)
# ax.set_ylabel('Depth (m)')
ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.legend(['Kita', 'Volcano O', 'Seamount C','Orca'])
ax.set_title('Oblique West of Axis')
plt.savefig('o2_caldera')

# %%
ax = df_o2_kita.plot(y='Elevation', label='kita')
df_o2_knoll['Elevation'].plot(ax=ax)
df_o2_tracy['Elevation'].plot(ax=ax)
df_o2_O['Elevation'].plot(ax=ax)
df_o2_wm['Elevation'].plot(ax=ax)
ax.set_ylabel('Elevation (m)')
ax.set_xlabel('Distance (m)')
ax.set_title('Oblique West of Axis')
ax.legend(['kita', 'knoll', 'tracy', 'volcano_o', 'wm'])
plt.savefig('o2')

# %%
ax = df_o2_tracy.plot(y='Elevation', label='tracy')
# df_aa_knoll['Elevation'].plot(ax=ax)
df_o2_O['Elevation'].plot(ax=ax)
df_o2_wm['Elevation'].plot(ax=ax)
# ax.set_ylabel('Depth (m)')
ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.legend(['tracy', 'volcano_o', 'wm', 'FirstRM'])
plt.savefig('o2_tracy_o_wm')
